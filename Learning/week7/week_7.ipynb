# %%
# !pip install nltk

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
import nltk
import string

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
text = "I love learning Artificial Intelligence! AI models are transforming the world."
print(text)
# Out:
# I love learning Artificial Intelligence! AI models are transforming the world.

# %%
text = text.lower()

text = text.translate(str.maketrans('', '', string.punctuation))

print(text)
nltk.download('punkt_tab')
# Out:
# i love learning artificial intelligence ai models are transforming the world
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
tokens = word_tokenize(text)
print(tokens)
# Out:
# ['i', 'love', 'learning', 'artificial', 'intelligence', 'ai', 'models', 'are', 'transforming', 'the', 'world']

# %%
stop_words = set(stopwords.words('english'))

filtered_words = []
for word in tokens:
    if word not in stop_words:
        filtered_words.append(word)

print(filtered_words)
# Out:
# ['love', 'learning', 'artificial', 'intelligence', 'ai', 'models', 'transforming', 'world']

# %%
stemmer = PorterStemmer()

stemmed_words = []

for word in filtered_words:
    stemmed_words.append(stemmer.stem(word))

print(stemmed_words)
# Out:
# ['love', 'learn', 'artifici', 'intellig', 'ai', 'model', 'transform', 'world']

# %%
lemmatizer = WordNetLemmatizer()

lemmatized_words = []

for word in filtered_words:
    lemmatized_words.append(lemmatizer.lemmatize(word))

print(lemmatized_words)
# Out:
# ['love', 'learning', 'artificial', 'intelligence', 'ai', 'model', 'transforming', 'world']

# %%
comparison = list(zip(filtered_words, stemmed_words, lemmatized_words))

for original, stem, lemma in comparison:
    print(f"{original} → {stem} → {lemma}")
# Out:
# love → love → love
# learning → learn → learning
# artificial → artifici → artificial
# intelligence → intellig → intelligence
# ai → ai → ai
# models → model → model
# transforming → transform → transforming
# world → world → world

# %%
comparison = list(zip(filtered_words, stemmed_words, lemmatized_words))

for original, stem, lemma in comparison:
    print(f"{original} → {stem} → {lemma}")
# Out:
# love → love → love
# learning → learn → learning
# artificial → artifici → artificial
# intelligence → intellig → intelligence
# ai → ai → ai
# models → model → model
# transforming → transform → transforming
# world → world → world

# %%
def preprocess_text(text):

    text = text.lower()
    text = text.translate(str.maketrans('', '', string.punctuation))

    tokens = word_tokenize(text)

    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]

    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(word) for word in tokens]

    return tokens


sample = "AI is changing the future of technology and innovation!"

print(preprocess_text(sample))
# Out:
# ['ai', 'changing', 'future', 'technology', 'innovation']
